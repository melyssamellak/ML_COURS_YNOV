# %%
import requests
import pandas as pd
import joblib
import numpy as np
from datetime import datetime

# ==========================
# 7️⃣  PRÉDICTION EN TEMPS RÉEL (API AviationStack)
# ==========================

API_KEY = "3057f8d1b6d9283ee6a287082a3388af"  
JFK_IATA = "JFK"  # Code IATA pour filtrer les vols au départ de JFK

# Charger le modèle entraîné
pipeline = joblib.load("best_flight_delay_model2.pkl")

# 🛫 **1. Récupération des vols en temps réel**
def fetch_live_flights():
    print("\n🔄 Récupération des vols en temps réel...")
    all_flights = []
    limit = 100  # Nombre maximal de résultats par requête
    offset = 0   # Début de la pagination

    while True:
        url = f"http://api.aviationstack.com/v1/flights?access_key={API_KEY}&dep_iata={JFK_IATA}&flight_status=active&limit={limit}&offset={offset}"
        response = requests.get(url)

        if response.status_code != 200:
            print(f"⚠️ Erreur API : {response.status_code}")
            break

        data = response.json().get("data", [])

        if not data:  # Arrêter la boucle si plus de résultats
            break

        all_flights.extend(data)
        offset += limit  # Passer à la page suivante
        print(f"✅ {len(all_flights)} vols récupérés jusqu'à présent...")

    print(f"✅ {len(all_flights)} vols au total récupérés avec succès.")
    return all_flights

# 🔄 **2. Transformation des données en format utilisable**
def prepare_live_data(flight_data, pipeline):
    if not flight_data:
        return None
    
    df_live = pd.DataFrame(flight_data)
    
    df_live['FL_DATE'] = pd.to_datetime(df_live['flight_date'])
    df_live['YEAR'] = df_live['FL_DATE'].dt.year
    df_live['MONTH'] = df_live['FL_DATE'].dt.month
    df_live['DAY'] = df_live['FL_DATE'].dt.day
    df_live['DAY_OF_WEEK'] = df_live['FL_DATE'].dt.dayofweek
    df_live['IS_WEEKEND'] = df_live['DAY_OF_WEEK'].apply(lambda x: 1 if x in [5, 6] else 0)
    
    df_live['SEASON'] = df_live['MONTH'].map({12: 'Winter', 1: 'Winter', 2: 'Winter',
                                              3: 'Spring', 4: 'Spring', 5: 'Spring',
                                              6: 'Summer', 7: 'Summer', 8: 'Summer',
                                              9: 'Autumn', 10: 'Autumn', 11: 'Autumn'})
    
    df_live['AIRLINE_CODE'] = df_live['airline'].apply(lambda x: x.get('iata', 'UNKNOWN'))
    df_live['DEST'] = df_live['arrival'].apply(lambda x: x.get('iata', 'UNKNOWN'))
    df_live['DEP_DELAY'] = df_live['departure'].apply(lambda x: x.get('delay', 0))
    df_live['HOUR'] = pd.to_datetime(df_live['departure'].apply(lambda x: x.get('scheduled', ''))).dt.hour
    
    def convert_to_hhmm(timestamp):
        if pd.isna(timestamp) or timestamp == "":
            return np.nan
        dt = pd.to_datetime(timestamp, errors='coerce')
        return dt.hour * 100 + dt.minute if not pd.isna(dt) else np.nan
    
    df_live['CRS_DEP_TIME'] = df_live['departure'].apply(lambda x: convert_to_hhmm(x.get('scheduled', '')))
    df_live['DEP_TIME'] = df_live['departure'].apply(lambda x: convert_to_hhmm(x.get('actual', x.get('estimated', x.get('scheduled', 0)))))
    df_live['WHEELS_OFF'] = df_live['departure'].apply(lambda x: convert_to_hhmm(x.get('actual_runway', x.get('estimated_runway', x.get('estimated', x.get('scheduled', 0))))))
    df_live['WHEELS_ON'] = df_live['arrival'].apply(lambda x: convert_to_hhmm(x.get('actual_runway', x.get('estimated_runway', x.get('estimated', x.get('scheduled', 0))))))
    
    def calculate_duration(start, end):
        if pd.isna(start) or pd.isna(end) or start == "" or end == "":
            return np.nan
        return (pd.to_datetime(end) - pd.to_datetime(start)).seconds // 60
    
    df_live['CRS_ELAPSED_TIME'] = df_live.apply(lambda x: calculate_duration(x['departure'].get('scheduled', ''), x['arrival'].get('scheduled', '')), axis=1)
    df_live['ELAPSED_TIME'] = df_live.apply(lambda x: calculate_duration(x['departure'].get('actual', x['departure'].get('estimated', x['departure'].get('scheduled', ''))),
                                                                          x['arrival'].get('actual', x['arrival'].get('estimated', x['arrival'].get('scheduled', '')))), axis=1)
    
    delay_keys = ['DELAY_DUE_CARRIER', 'DELAY_DUE_WEATHER', 'DELAY_DUE_NAS', 'DELAY_DUE_SECURITY', 'DELAY_DUE_LATE_AIRCRAFT']
    for key in delay_keys:
        df_live[key] = 0
    
    nan_columns = df_live.columns[df_live.isna().any()].tolist()
    if nan_columns:
        print(f"⚠️ Colonnes avec NaN après transformation: {nan_columns}")
    
    df_live.fillna(0, inplace=True)
    return df_live

# 🚀 **3. Prédiction des retards en temps réel**
def predict_scheduled_flights():
    live_flights = fetch_live_flights()
    if not live_flights:
        return

    live_data = prepare_live_data(live_flights, pipeline)
    if live_data is None:
        return
    
    if live_data.isnull().sum().sum() > 0:
        print("⚠️ Des valeurs NaN subsistent après le traitement des données. Vérifiez l'API.")
        return
    
    predictions = pipeline.predict(live_data)

    print("\n📊 **Prédictions des Retards de Vols SCHEDULED au départ de JFK :**\n")
    for i, flight in enumerate(live_flights):
        print(f"✈️ Vol {flight['flight']['iata']} à destination de {flight['arrival']['iata']}")
        print(f"   🕒 Départ prévu : {flight['departure']['scheduled']}")
        print(f"   🔹 Prédiction de retard : {predictions[i]:.2f} min\n")

# Exécuter la prédiction en temps réel
predict_scheduled_flights()
# Out:
# 🔄 Récupération des vols en temps réel...
# ✅ 100 vols SCHEDULED au départ de JFK récupérés avec succès.
# ⚠️ Colonnes avec NaN après transformation: ['aircraft', 'live', 'AIRLINE_CODE', 'WHEELS_ON', 'ELAPSED_TIME']
#
# 📊 **Prédictions des Retards de Vols SCHEDULED au départ de JFK :**
#
# ✈️ Vol CA982 à destination de PEK
#    🕒 Départ prévu : 2025-03-17T02:05:00+00:00
#    🔹 Prédiction de retard : 15.63 min
#
# ✈️ Vol SV6869 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 21.83 min
#
# ✈️ Vol VS2492 à destination de SAV
#    🕒 Départ prévu : 2025-03-17T13:59:00+00:00
#    🔹 Prédiction de retard : 16.03 min
#
# ✈️ Vol KE7369 à destination de SAV
#    🕒 Départ prévu : 2025-03-17T13:59:00+00:00
#    🔹 Prédiction de retard : 16.03 min
#
# ✈️ Vol AF2386 à destination de SAV
#    🕒 Départ prévu : 2025-03-17T13:59:00+00:00
#    🔹 Prédiction de retard : 16.03 min
#
# ✈️ Vol AD7617 à destination de FLL
#    🕒 Départ prévu : 2025-03-17T13:29:00+00:00
#    🔹 Prédiction de retard : 20.87 min
#
# ✈️ Vol EY8343 à destination de FLL
#    🕒 Départ prévu : 2025-03-17T13:29:00+00:00
#    🔹 Prédiction de retard : 20.87 min
#
# ✈️ Vol MH9211 à destination de HKG
#    🕒 Départ prévu : 2025-03-17T01:55:00+00:00
#    🔹 Prédiction de retard : 15.62 min
#
# ✈️ Vol LA5649 à destination de HKG
#    🕒 Départ prévu : 2025-03-17T01:55:00+00:00
#    🔹 Prédiction de retard : 15.62 min
#
# ✈️ Vol OM5843 à destination de HKG
#    🕒 Départ prévu : 2025-03-17T01:55:00+00:00
#    🔹 Prédiction de retard : 15.62 min
#
# ✈️ Vol AS36 à destination de SFO
#    🕒 Départ prévu : 2025-03-17T09:30:00+00:00
#    🔹 Prédiction de retard : 18.99 min
#
# ✈️ Vol AS39 à destination de PSP
#    🕒 Départ prévu : 2025-03-17T09:30:00+00:00
#    🔹 Prédiction de retard : 15.97 min
#
# ✈️ Vol B6623 à destination de LAX
#    🕒 Départ prévu : 2025-03-17T09:59:00+00:00
#    🔹 Prédiction de retard : 19.14 min
#
# ✈️ Vol BA178 à destination de LHR
#    🕒 Départ prévu : 2025-03-17T09:05:00+00:00
#    🔹 Prédiction de retard : 16.46 min
#
# ✈️ Vol None à destination de IAD
#    🕒 Départ prévu : 2025-03-17T09:00:00+00:00
#    🔹 Prédiction de retard : 32.06 min
#
# ✈️ Vol VS26 à destination de LHR
#    🕒 Départ prévu : 2025-03-17T09:00:00+00:00
#    🔹 Prédiction de retard : 19.53 min
#
# ✈️ Vol AA2829 à destination de PHX
#    🕒 Départ prévu : 2025-03-17T13:00:00+00:00
#    🔹 Prédiction de retard : 16.16 min
#
# ✈️ Vol AF8731 à destination de ORF
#    🕒 Départ prévu : 2025-03-17T15:20:00+00:00
#    🔹 Prédiction de retard : 15.78 min
#
# ✈️ Vol KE7351 à destination de ORF
#    🕒 Départ prévu : 2025-03-17T15:20:00+00:00
#    🔹 Prédiction de retard : 15.78 min
#
# ✈️ Vol KL6249 à destination de ORF
#    🕒 Départ prévu : 2025-03-17T15:20:00+00:00
#    🔹 Prédiction de retard : 15.78 min
#
# ✈️ Vol VS3569 à destination de ORF
#    🕒 Départ prévu : 2025-03-17T15:20:00+00:00
#    🔹 Prédiction de retard : 15.78 min
#
# ✈️ Vol QR9523 à destination de IND
#    🕒 Départ prévu : 2025-03-17T14:30:00+00:00
#    🔹 Prédiction de retard : 18.16 min
#
# ✈️ Vol BA5399 à destination de IND
#    🕒 Départ prévu : 2025-03-17T14:30:00+00:00
#    🔹 Prédiction de retard : 18.16 min
#
# ✈️ Vol KL5876 à destination de SDQ
#    🕒 Départ prévu : 2025-03-17T14:25:00+00:00
#    🔹 Prédiction de retard : 19.26 min
#
# ✈️ Vol B6609 à destination de SDQ
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 21.05 min
#
# ✈️ Vol DL1855 à destination de STI
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 20.58 min
#
# ✈️ Vol DL5150 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 21.84 min
#
# ✈️ Vol F93545 à destination de SJU
#    🕒 Départ prévu : 2025-03-17T15:01:00+00:00
#    🔹 Prédiction de retard : 20.85 min
#
# ✈️ Vol B61111 à destination de CUR
#    🕒 Départ prévu : 2025-03-17T10:30:00+00:00
#    🔹 Prédiction de retard : -8.15 min
#
# ✈️ Vol CI5321 à destination de ANC
#    🕒 Départ prévu : 2025-03-17T10:50:00+00:00
#    🔹 Prédiction de retard : 15.96 min
#
# ✈️ Vol B6939 à destination de SJD
#    🕒 Départ prévu : 2025-03-17T11:01:00+00:00
#    🔹 Prédiction de retard : 18.23 min
#
# ✈️ Vol AA1327 à destination de CUN
#    🕒 Départ prévu : 2025-03-17T11:00:00+00:00
#    🔹 Prédiction de retard : 30.23 min
#
# ✈️ Vol QR3985 à destination de SJD
#    🕒 Départ prévu : 2025-03-17T11:01:00+00:00
#    🔹 Prédiction de retard : 18.22 min
#
# ✈️ Vol KE7339 à destination de MCO
#    🕒 Départ prévu : 2025-03-17T13:10:00+00:00
#    🔹 Prédiction de retard : 20.30 min
#
# ✈️ Vol KQ7011 à destination de MCO
#    🕒 Départ prévu : 2025-03-17T13:10:00+00:00
#    🔹 Prédiction de retard : 20.30 min
#
# ✈️ Vol QR4094 à destination de PUJ
#    🕒 Départ prévu : 2025-03-17T13:30:00+00:00
#    🔹 Prédiction de retard : 20.78 min
#
# ✈️ Vol QR3964 à destination de CUR
#    🕒 Départ prévu : 2025-03-17T10:30:00+00:00
#    🔹 Prédiction de retard : -8.22 min
#
# ✈️ Vol DL2093 à destination de TPA
#    🕒 Départ prévu : 2025-03-17T15:30:00+00:00
#    🔹 Prédiction de retard : 19.67 min
#
# ✈️ Vol HA4896 à destination de PSP
#    🕒 Départ prévu : 2025-03-17T09:30:00+00:00
#    🔹 Prédiction de retard : 16.22 min
#
# ✈️ Vol SQ1257 à destination de SFO
#    🕒 Départ prévu : 2025-03-17T09:30:00+00:00
#    🔹 Prédiction de retard : 18.99 min
#
# ✈️ Vol QR2071 à destination de SFO
#    🕒 Départ prévu : 2025-03-17T09:30:00+00:00
#    🔹 Prédiction de retard : 18.99 min
#
# ✈️ Vol HA4900 à destination de SFO
#    🕒 Départ prévu : 2025-03-17T09:30:00+00:00
#    🔹 Prédiction de retard : 18.99 min
#
# ✈️ Vol AA4658 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T15:15:00+00:00
#    🔹 Prédiction de retard : 21.23 min
#
# ✈️ Vol QR3871 à destination de AUA
#    🕒 Départ prévu : 2025-03-17T11:35:00+00:00
#    🔹 Prédiction de retard : -0.58 min
#
# ✈️ Vol LA6253 à destination de MCO
#    🕒 Départ prévu : 2025-03-17T13:10:00+00:00
#    🔹 Prédiction de retard : 20.30 min
#
# ✈️ Vol SV6865 à destination de MCO
#    🕒 Départ prévu : 2025-03-17T13:10:00+00:00
#    🔹 Prédiction de retard : 20.30 min
#
# ✈️ Vol VS4841 à destination de MCO
#    🕒 Départ prévu : 2025-03-17T13:10:00+00:00
#    🔹 Prédiction de retard : 20.30 min
#
# ✈️ Vol DL5460 à destination de SAV
#    🕒 Départ prévu : 2025-03-17T13:59:00+00:00
#    🔹 Prédiction de retard : 16.04 min
#
# ✈️ Vol B61769 à destination de GYE
#    🕒 Départ prévu : 2025-03-17T13:30:00+00:00
#    🔹 Prédiction de retard : 15.63 min
#
# ✈️ Vol B61669 à destination de PUJ
#    🕒 Départ prévu : 2025-03-17T13:30:00+00:00
#    🔹 Prédiction de retard : 20.85 min
#
# ✈️ Vol B61401 à destination de FLL
#    🕒 Départ prévu : 2025-03-17T13:29:00+00:00
#    🔹 Prédiction de retard : 20.94 min
#
# ✈️ Vol AF2444 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 21.83 min
#
# ✈️ Vol KE7361 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 21.83 min
#
# ✈️ Vol AF8559 à destination de SYR
#    🕒 Départ prévu : 2025-03-17T14:54:00+00:00
#    🔹 Prédiction de retard : 21.11 min
#
# ✈️ Vol KE7371 à destination de SYR
#    🕒 Départ prévu : 2025-03-17T14:54:00+00:00
#    🔹 Prédiction de retard : 21.11 min
#
# ✈️ Vol KL5616 à destination de SYR
#    🕒 Départ prévu : 2025-03-17T14:54:00+00:00
#    🔹 Prédiction de retard : 21.11 min
#
# ✈️ Vol KQ7064 à destination de SYR
#    🕒 Départ prévu : 2025-03-17T14:54:00+00:00
#    🔹 Prédiction de retard : 21.11 min
#
# ✈️ Vol VS3545 à destination de SYR
#    🕒 Départ prévu : 2025-03-17T14:54:00+00:00
#    🔹 Prédiction de retard : 21.11 min
#
# ✈️ Vol EY8378 à destination de SRQ
#    🕒 Départ prévu : 2025-03-17T13:45:00+00:00
#    🔹 Prédiction de retard : 15.60 min
#
# ✈️ Vol JL5846 à destination de SRQ
#    🕒 Départ prévu : 2025-03-17T13:45:00+00:00
#    🔹 Prédiction de retard : 15.60 min
#
# ✈️ Vol LY8748 à destination de SRQ
#    🕒 Départ prévu : 2025-03-17T13:45:00+00:00
#    🔹 Prédiction de retard : 15.60 min
#
# ✈️ Vol QR4111 à destination de SRQ
#    🕒 Départ prévu : 2025-03-17T13:45:00+00:00
#    🔹 Prédiction de retard : 15.60 min
#
# ✈️ Vol QR4098 à destination de STI
#    🕒 Départ prévu : 2025-03-17T12:35:00+00:00
#    🔹 Prédiction de retard : 15.93 min
#
# ✈️ Vol VS4721 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 21.83 min
#
# ✈️ Vol AA142 à destination de LHR
#    🕒 Départ prévu : 2025-03-17T11:10:00+00:00
#    🔹 Prédiction de retard : 1.76 min
#
# ✈️ Vol B61457 à destination de AUA
#    🕒 Départ prévu : 2025-03-17T11:35:00+00:00
#    🔹 Prédiction de retard : -0.56 min
#
# ✈️ Vol B6871 à destination de SLC
#    🕒 Départ prévu : 2025-03-17T11:30:00+00:00
#    🔹 Prédiction de retard : 21.24 min
#
# ✈️ Vol AS27 à destination de SEA
#    🕒 Départ prévu : 2025-03-17T11:30:00+00:00
#    🔹 Prédiction de retard : 24.44 min
#
# ✈️ Vol DL1908 à destination de SDQ
#    🕒 Départ prévu : 2025-03-17T14:25:00+00:00
#    🔹 Prédiction de retard : 19.34 min
#
# ✈️ Vol QR4046 à destination de SDQ
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 20.98 min
#
# ✈️ Vol VS4893 à destination de TPA
#    🕒 Départ prévu : 2025-03-17T15:30:00+00:00
#    🔹 Prédiction de retard : 19.67 min
#
# ✈️ Vol LA6159 à destination de TPA
#    🕒 Départ prévu : 2025-03-17T15:30:00+00:00
#    🔹 Prédiction de retard : 19.67 min
#
# ✈️ Vol KL7171 à destination de TPA
#    🕒 Départ prévu : 2025-03-17T15:30:00+00:00
#    🔹 Prédiction de retard : 19.67 min
#
# ✈️ Vol KE7375 à destination de TPA
#    🕒 Départ prévu : 2025-03-17T15:30:00+00:00
#    🔹 Prédiction de retard : 19.67 min
#
# ✈️ Vol AF5937 à destination de TPA
#    🕒 Départ prévu : 2025-03-17T15:30:00+00:00
#    🔹 Prédiction de retard : 19.67 min
#
# ✈️ Vol QR3939 à destination de RSW
#    🕒 Départ prévu : 2025-03-17T14:00:00+00:00
#    🔹 Prédiction de retard : 16.01 min
#
# ✈️ Vol LY8712 à destination de RSW
#    🕒 Départ prévu : 2025-03-17T14:00:00+00:00
#    🔹 Prédiction de retard : 16.01 min
#
# ✈️ Vol JL5844 à destination de RSW
#    🕒 Départ prévu : 2025-03-17T14:00:00+00:00
#    🔹 Prédiction de retard : 16.01 min
#
# ✈️ Vol HA2044 à destination de RSW
#    🕒 Départ prévu : 2025-03-17T14:00:00+00:00
#    🔹 Prédiction de retard : 16.29 min
#
# ✈️ Vol EY8362 à destination de RSW
#    🕒 Départ prévu : 2025-03-17T14:00:00+00:00
#    🔹 Prédiction de retard : 16.01 min
#
# ✈️ Vol TG6267 à destination de TPE
#    🕒 Départ prévu : 2025-03-17T01:05:00+00:00
#    🔹 Prédiction de retard : 26.30 min
#
# ✈️ Vol CM8016 à destination de TPE
#    🕒 Départ prévu : 2025-03-17T01:05:00+00:00
#    🔹 Prédiction de retard : 26.30 min
#
# ✈️ Vol AV4506 à destination de TPE
#    🕒 Départ prévu : 2025-03-17T01:05:00+00:00
#    🔹 Prédiction de retard : 26.30 min
#
# ✈️ Vol KQ7048 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 21.83 min
#
# ✈️ Vol KL5614 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 21.83 min
#
# ✈️ Vol AF8725 à destination de STI
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 20.57 min
#
# ✈️ Vol QR3878 à destination de CUN
#    🕒 Départ prévu : 2025-03-17T12:50:00+00:00
#    🔹 Prédiction de retard : -1.89 min
#
# ✈️ Vol LA6153 à destination de SJU
#    🕒 Départ prévu : 2025-03-17T12:55:00+00:00
#    🔹 Prédiction de retard : 18.63 min
#
# ✈️ Vol VS3162 à destination de SJU
#    🕒 Départ prévu : 2025-03-17T12:55:00+00:00
#    🔹 Prédiction de retard : 18.63 min
#
# ✈️ Vol WS7243 à destination de SJU
#    🕒 Départ prévu : 2025-03-17T12:55:00+00:00
#    🔹 Prédiction de retard : 18.63 min
#
# ✈️ Vol KL7004 à destination de STI
#    🕒 Départ prévu : 2025-03-17T14:55:00+00:00
#    🔹 Prédiction de retard : 20.57 min
#
# ✈️ Vol QR2584 à destination de CUN
#    🕒 Départ prévu : 2025-03-17T11:00:00+00:00
#    🔹 Prédiction de retard : 30.23 min
#
# ✈️ Vol QR8594 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T15:15:00+00:00
#    🔹 Prédiction de retard : 21.23 min
#
# ✈️ Vol QF4511 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T15:15:00+00:00
#    🔹 Prédiction de retard : 21.23 min
#
# ✈️ Vol IB4580 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T15:15:00+00:00
#    🔹 Prédiction de retard : 21.23 min
#
# ✈️ Vol G36407 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T15:15:00+00:00
#    🔹 Prédiction de retard : 21.23 min
#
# ✈️ Vol CX7532 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T15:15:00+00:00
#    🔹 Prédiction de retard : 21.23 min
#
# ✈️ Vol BA4711 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T15:15:00+00:00
#    🔹 Prédiction de retard : 21.23 min
#
# ✈️ Vol AT5137 à destination de RDU
#    🕒 Départ prévu : 2025-03-17T15:15:00+00:00
#    🔹 Prédiction de retard : 21.23 min
#
# ✈️ Vol AF8789 à destination de SDQ
#    🕒 Départ prévu : 2025-03-17T14:25:00+00:00
#    🔹 Prédiction de retard : 19.34 min
